# %% [markdown]
# Cell 1 loads up all the libraries we are using. In the first lessons, we used fastAI, while in this one we use Tensorflow with Keras. Both of these are large libraries, and its designers decided to allow programmers to load only the pieces that are relevant, which is what the 'from keras.XXX import YYY' lines do--they load just the partrt of Keras (or other library) that we want. This makes the load time faster and the final running program smaller.
#
# The second half of this cell does the familiar step of loading the data sets that I have prepared, which in this case are a series of abdominal CTs as well as hand-traced masks of the Pancreas, courtesy of The Cancer Image Archive: http://TheCancerImageArchive....

# %%
#Cell 1
# %tensorflow_version 1.x 
# !pip install -q keras
# !pip install natsort
import numpy as np
import numpy.ma as ma
import os
import shutil
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, Dense, Dropout, Activation, Flatten, BatchNormalization, Reshape
from keras.engine.topology import Layer

from keras.layers.merge import concatenate, add
from keras.layers.core import Lambda
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
from keras import backend as K
from keras.utils.generic_utils import get_custom_objects
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import imageio
from natsort import natsorted
import random
import warnings
warnings.filterwarnings("ignore")

from google.colab import drive
drive.mount('/content/gdrive/')

# !rm -rf trainimages
# !mkdir trainimages
# !rm -rf trainmasks
# !mkdir trainmasks

# !rm -rf validationimages
# !mkdir validationimages
# !rm -rf validationmasks
# !mkdir validationmasks

# !rm -rf testimages
# !mkdir testimages
# !rm -rf testmasks
# !mkdir testmasks

# !unzip -q -o /content/gdrive/My\ Drive/CNT/DeepResection/Unet_trial.zip
# !mv Unet_trial/trainimages/* trainimages/
# !mv Unet_trial/trainmasks/* trainmasks/
# !mv Unet_trial/validationimages/* validationimages/
# !mv Unet_trial/validationmasks/* validationmasks/
# !mv Unet_trial/testimages/* testimages/
# !mv Unet_trial/testmasks/* testmasks/
# Out:
# Requirement already satisfied: natsort in /usr/local/lib/python3.6/dist-packages (5.5.0)
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !ls trainimages
# Out:
# 25_f_img_001.png  31_h_img_089.png   pat15_img_027.png	pat24_img_015.png
# 25_f_img_002.png  31_h_img_090.png   pat15_img_028.png	pat24_img_016.png
# 25_f_img_003.png  31_h_img_091.png   pat15_img_029.png	pat24_img_017.png
# 25_f_img_004.png  31_h_img_092.png   pat15_img_030.png	pat24_img_018.png
# 25_f_img_005.png  31_h_img_093.png   pat15_img_031.png	pat24_img_019.png
# 25_f_img_006.png  31_h_img_094.png   pat15_img_032.png	pat24_img_020.png
# 25_f_img_007.png  31_h_img_095.png   pat15_img_033.png	pat24_img_021.png
# 25_f_img_008.png  31_h_img_096.png   pat15_img_034.png	pat24_img_022.png
# 25_f_img_009.png  31_h_img_097.png   pat15_img_035.png	pat24_img_023.png
# 25_f_img_010.png  31_h_img_098.png   pat15_img_036.png	pat24_img_024.png
# 25_f_img_011.png  31_h_img_099.png   pat15_img_037.png	pat24_img_025.png
# 25_f_img_012.png  31_h_img_100.png   pat15_img_038.png	pat24_img_026.png
# 25_f_img_013.png  31_h_img_101.png   pat15_img_039.png	pat24_img_027.png
# 31_h_img_072.png  pat15_img_010.png  pat23_img_148.png	pat32_img_136.png
# 31_h_img_073.png  pat15_img_011.png  pat23_img_149.png	pat32_img_137.png
# 31_h_img_074.png  pat15_img_012.png  pat23_img_150.png	pat32_img_138.png
# 31_h_img_075.png  pat15_img_013.png  pat24_img_001.png	pat32_img_139.png
# 31_h_img_076.png  pat15_img_014.png  pat24_img_002.png	pat32_img_140.png
# 31_h_img_077.png  pat15_img_015.png  pat24_img_003.png	pat32_img_141.png
# 31_h_img_078.png  pat15_img_016.png  pat24_img_004.png	pat32_img_142.png
# 31_h_img_079.png  pat15_img_017.png  pat24_img_005.png	pat32_img_143.png
# 31_h_img_080.png  pat15_img_018.png  pat24_img_006.png	pat32_img_144.png
# 31_h_img_081.png  pat15_img_019.png  pat24_img_007.png	pat32_img_145.png
# 31_h_img_082.png  pat15_img_020.png  pat24_img_008.png	pat32_img_146.png
# 31_h_img_083.png  pat15_img_021.png  pat24_img_009.png	pat32_img_147.png
# 31_h_img_084.png  pat15_img_022.png  pat24_img_010.png	pat32_img_148.png
# 31_h_img_085.png  pat15_img_023.png  pat24_img_011.png	pat32_img_149.png
# 31_h_img_086.png  pat15_img_024.png  pat24_img_012.png	pat32_img_150.png
# 31_h_img_087.png  pat15_img_025.png  pat24_img_013.png
# 31_h_img_088.png  pat15_img_026.png  pat24_img_014.png

# %% [markdown]
# #Data Wrangling
# Here we organize the data into training, validation and testing sets, with each having an image and mask, so 6 directories total. I started with the TCIA-Pancreas data set, which has hand-traced contours of the pancreas.
# I took each image that had some pancreas traced, applied 400/40 W/L settings, converted to 8 bits, and then cropped to the central 256x256 (just to reduce memory demands). The mask is also cropped to match, and is either o or 1.
# THese are then loaded into the respective memory arrays.

# %%
# Cell 2

train_X = []
train_Y = []
val_X = []
val_Y = []
test_X = []
test_Y = []

im_list = natsorted(os.listdir('./trainimages'))
for f in im_list:
  pth = './trainimages/' + f 
  img = imageio.imread(pth)
  train_X.append(np.array(img))
train_X = np.array(train_X)
train_X = train_X/255
train_X = train_X[..., np.newaxis]

im_list = natsorted(os.listdir('./trainmasks'))
for f in im_list:
  pth = './trainmasks/' + f 
  img = imageio.imread(pth)
  train_Y.append(np.array(img))
train_Y = np.array(train_Y)
train_Y = (train_Y > 0).astype(np.float32)
train_Y = train_Y[..., np.newaxis]

im_list = natsorted(os.listdir('./validationimages'))
for f in im_list:
  pth = './validationimages/' + f 
  img = imageio.imread(pth)
  val_X.append(np.array(img))
val_X = np.array(val_X)
val_X = val_X/255
val_X = val_X[..., np.newaxis]

im_list = natsorted(os.listdir('./validationmasks'))
for f in im_list:
  pth = './validationmasks/' + f 
  img = imageio.imread(pth)
  val_Y.append(np.array(img))
val_Y = np.array(val_Y)
val_Y = (val_Y > 0).astype(np.float32)
val_Y = val_Y[..., np.newaxis]

im_list = natsorted(os.listdir('./testimages'))
for f in im_list:
  pth = './testimages/' + f 
  img = imageio.imread(pth)
  test_X.append(np.array(img))
test_X = np.array(test_X)
test_X = test_X/255
test_X = test_X[..., np.newaxis]

im_list = natsorted(os.listdir('./testmasks'))
for f in im_list:
  pth = './testmasks/' + f 
  img = imageio.imread(pth)
  test_Y.append(np.array(img))
test_Y = np.array(test_Y)
test_Y = (test_Y > 0).astype(np.float32)
test_Y = test_Y[..., np.newaxis]

print(train_X.shape[0],"images for training,", val_X.shape[0], "images for validation, and", test_X.shape[0], "images for testing")

WIDTH = train_X.shape[2]
HEIGHT = train_X.shape[1]
CHANNELS = 1
#print ('X and Y dims are ' + str(WIDTH) + 'x' + str(HEIGHT))
# Out:
# 3550 images for training, 1070 images for validation, and 1070 images for testing

# %% [markdown]
# #Cost Functions
# A critical element of every machine learning algorithm is to select a good cost function. In the classificaiton problems of prior articles, we used the accuracy of predictions as the cost function. For segmentation, one potentially could compute a score for teh classification of each pixel (object or not object), but a more common metric is the Dice Similiarity Score (a.k.a. Dice Score). This essentially means the amount of overlap between the gold standard and the prediction. If they perfectly agree, the Dice Score is 1, and if there is no overlap, the score is 0. We can convert the Dice Score toa Dice Loss by subtracting it from 1. One can also convert the Dice Score to a cross-entropy function, and this can work well in some cases. Code for both is provided, and you are encouraged to try both cost functions to see the effect. Note, however, that the above can result in Dice values of zero, and we don't want to divide by zero. In fact, we don't want to divide by a small number, so we add 'smooth' to the value (in our case we are using 1) so the values of Dice actually are 1 to 2, not 0 to 1. And that means the Dice Loss will be -1 to 0, but the loss reported is the sum, so it will have a larger range.

# %%
# Cell 3
def dice_coeff(y_true, y_pred):
    # add epsilon to avoid a divide by 0 error in case a slice has no pixels set
    # we only care about relative value, not absolute so this alteration doesn't matter
    _epsilon = 10 ** -7
    intersections = tf.reduce_sum(y_true * y_pred)
    unions = tf.reduce_sum(y_true + y_pred)
    dice_scores = (2.0 * intersections + _epsilon) / (unions + _epsilon)
    return dice_scores

def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss
  
get_custom_objects().update({"dice": dice_loss})

class LayerNormalization (Layer) :
    
    def call(self, x, mask=None, training=None) :
        axis = list (range (1, len (x.shape)))
        x /= K.std (x, axis = axis, keepdims = True) + K.epsilon()
        x -= K.mean (x, axis = axis, keepdims = True)
        return x
        
    def compute_output_shape(self, input_shape):
        return input_shape

# %% [markdown]
# #Building the U-Net
# We are finally ready to build our Network. One difference of Keras versus the previous examples of FastAI is that Keras is designed so that there is one line of code for each layer of the network (plus the setup and training/evlauation code). This means that for a moderately complex network like a ResNet34 classifier, there would be 34 lines of code. U-Nets are popular network architectures for segmentation. These get their name because of the unique way they are built: The first part produces repeated reductions in resolution as the 'important' parts of the image are retained that reflect the structures that it is trained to recognize. Typically there are 4 or 5 such reduction layers that each consist of convultions, ReLUs, and Pooling layers. Once the image is reduced to the critical components, the networks begins to reconstruct the precise margins of the critical elements by using 'skip layers'. As the resolution is stored using convolutional-transpose layers, the layers 'look' back to the layers where the resolution was reduced to try to best define the margins of the structures. See Ronneberger (Ronneberger, Olaf; Fischer, Philipp; Brox, Thomas (2015). "U-Net: Convolutional Networks for Biomedical Image Segmentation". arXiv:1505.04597  https://arxiv.org/pdf/1505.04597.pdf).
#
# There is a lot more going on that I will only provide references to (these will be covered in the future):
# 1. ReLU Activation Function: https://arxiv.org/pdf/1502.01852.pdf
# 2. Kernel Intialization (the weights loaded into the network before anything is done): https://arxiv.org/pdf/1502.01852.pdf
# 3. Transpose Convolution: https://medium.com/apache-mxnet/transposed-convolutions-explained-with-ms-excel-52d13030c7e8#Building the U-Net

# %%
# Cell 4
def build_model(act_fn = 'relu', init_fn = 'he_normal', width=256, height = 256, channels = 1): 
    inputs = Input((width,height,channels))

    # note we use linear function before layer normalization
    conv1 = Conv2D(8, 5, activation = 'linear', padding = 'same', kernel_initializer = init_fn)(inputs)
    conv1 = LayerNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(16, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(pool1)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(32, 3, activation = 'linear', padding = 'same', kernel_initializer = init_fn)(pool2)
    conv3 = LayerNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(64, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(pool3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(72, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(pool4)

    up6 = Conv2D(64, 2, activation = 'linear', padding = 'same', kernel_initializer = init_fn)(UpSampling2D(size = (2,2))(conv5))
    up6 = LayerNormalization()(up6)
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(64, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(merge6)

    up7 = Conv2D(32, 2, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(32, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(merge7)

    up8 = Conv2D(16, 2, activation = 'linear', padding = 'same', kernel_initializer = init_fn)(UpSampling2D(size = (2,2))(conv7))
    up8 = LayerNormalization()(up8)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(16, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(merge8)

    up9 = Conv2D(8, 2, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(8, 3, activation = act_fn, padding = 'same', kernel_initializer = init_fn)(merge9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
    model = Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = 'dice', metrics=[dice_coeff])
    return model

# %% [markdown]
# #Train it
# Now that our model is built, we are (finally!) ready to train it. Trial and error with colab hardware (K80) has shown that a batch_size of 16 works, and that we can get reasonable results adfter 5 epochs (but you can train longer to get better results)

# %%
# Cell 5
model = build_model(act_fn = 'relu', init_fn = 'he_normal', width=WIDTH, height = HEIGHT, channels = CHANNELS)

checkpointer = ModelCheckpoint('model.h5', verbose=1, save_best_only=True)

###########  I get 75 seconds per epoch on colab notebook (K80s). so 20 epochs is almost 30 minutes
###########  It will take a couple of hours to get pretty good results, but 25 gets reasonable enough considering difficulty of pancreas
epochs = 100
batch_size = 64
results = model.fit(train_X, train_Y, validation_data=(val_X, val_Y), batch_size=batch_size, epochs=epochs, callbacks=[checkpointer])
# Out:
# Train on 3550 samples, validate on 1070 samples
# Epoch 1/100
# 3550/3550 [==============================] - 45s 13ms/step - loss: 0.9918 - dice_coeff: 0.0083 - val_loss: 0.9906 - val_dice_coeff: 0.0092
#
# Epoch 00001: val_loss improved from inf to 0.99063, saving model to model.h5
# Epoch 2/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.9564 - dice_coeff: 0.0437 - val_loss: 0.9310 - val_dice_coeff: 0.0678
#
# Epoch 00002: val_loss improved from 0.99063 to 0.93103, saving model to model.h5
# Epoch 3/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.6184 - dice_coeff: 0.3831 - val_loss: 0.8396 - val_dice_coeff: 0.1578
#
# Epoch 00003: val_loss improved from 0.93103 to 0.83957, saving model to model.h5
# Epoch 4/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.3943 - dice_coeff: 0.6018 - val_loss: 0.8083 - val_dice_coeff: 0.1885
#
# Epoch 00004: val_loss improved from 0.83957 to 0.80828, saving model to model.h5
# Epoch 5/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.3407 - dice_coeff: 0.6610 - val_loss: 0.8640 - val_dice_coeff: 0.1337
#
# Epoch 00005: val_loss did not improve from 0.80828
# Epoch 6/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.3119 - dice_coeff: 0.6827 - val_loss: 0.7521 - val_dice_coeff: 0.2438
#
# Epoch 00006: val_loss improved from 0.80828 to 0.75205, saving model to model.h5
# Epoch 7/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2990 - dice_coeff: 0.7014 - val_loss: 0.7653 - val_dice_coeff: 0.2308
#
# Epoch 00007: val_loss did not improve from 0.75205
# Epoch 8/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2671 - dice_coeff: 0.7340 - val_loss: 0.7896 - val_dice_coeff: 0.2069
#
# Epoch 00008: val_loss did not improve from 0.75205
# Epoch 9/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2538 - dice_coeff: 0.7466 - val_loss: 0.7569 - val_dice_coeff: 0.2390
#
# Epoch 00009: val_loss did not improve from 0.75205
# Epoch 10/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2444 - dice_coeff: 0.7556 - val_loss: 0.7949 - val_dice_coeff: 0.2017
#
# Epoch 00010: val_loss did not improve from 0.75205
# Epoch 11/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2321 - dice_coeff: 0.7670 - val_loss: 0.7666 - val_dice_coeff: 0.2296
#
# Epoch 00011: val_loss did not improve from 0.75205
# Epoch 12/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2218 - dice_coeff: 0.7775 - val_loss: 0.7606 - val_dice_coeff: 0.2354
#
# Epoch 00012: val_loss did not improve from 0.75205
# Epoch 13/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2224 - dice_coeff: 0.7779 - val_loss: 0.8179 - val_dice_coeff: 0.1791
#
# Epoch 00013: val_loss did not improve from 0.75205
# Epoch 14/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2206 - dice_coeff: 0.7787 - val_loss: 0.7780 - val_dice_coeff: 0.2184
#
# Epoch 00014: val_loss did not improve from 0.75205
# Epoch 15/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2140 - dice_coeff: 0.7857 - val_loss: 0.7575 - val_dice_coeff: 0.2385
#
# Epoch 00015: val_loss did not improve from 0.75205
# Epoch 16/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.2013 - dice_coeff: 0.7990 - val_loss: 0.7751 - val_dice_coeff: 0.2212
#
# Epoch 00016: val_loss did not improve from 0.75205
# Epoch 17/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1927 - dice_coeff: 0.8069 - val_loss: 0.7642 - val_dice_coeff: 0.2319
#
# Epoch 00017: val_loss did not improve from 0.75205
# Epoch 18/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1902 - dice_coeff: 0.8102 - val_loss: 0.7474 - val_dice_coeff: 0.2484
#
# Epoch 00018: val_loss improved from 0.75205 to 0.74738, saving model to model.h5
# Epoch 19/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1843 - dice_coeff: 0.8159 - val_loss: 0.7545 - val_dice_coeff: 0.2414
#
# Epoch 00019: val_loss did not improve from 0.74738
# Epoch 20/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1816 - dice_coeff: 0.8175 - val_loss: 0.7429 - val_dice_coeff: 0.2528
#
# Epoch 00020: val_loss improved from 0.74738 to 0.74290, saving model to model.h5
# Epoch 21/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1811 - dice_coeff: 0.8187 - val_loss: 0.7934 - val_dice_coeff: 0.2032
#
# Epoch 00021: val_loss did not improve from 0.74290
# Epoch 22/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1888 - dice_coeff: 0.8119 - val_loss: 0.7649 - val_dice_coeff: 0.2312
#
# Epoch 00022: val_loss did not improve from 0.74290
# Epoch 23/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1756 - dice_coeff: 0.8246 - val_loss: 0.7475 - val_dice_coeff: 0.2483
#
# Epoch 00023: val_loss did not improve from 0.74290
# Epoch 24/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1740 - dice_coeff: 0.8263 - val_loss: 0.7683 - val_dice_coeff: 0.2279
#
# Epoch 00024: val_loss did not improve from 0.74290
# Epoch 25/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1599 - dice_coeff: 0.8398 - val_loss: 0.7736 - val_dice_coeff: 0.2227
#
# Epoch 00025: val_loss did not improve from 0.74290
# Epoch 26/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1599 - dice_coeff: 0.8404 - val_loss: 0.7537 - val_dice_coeff: 0.2422
#
# Epoch 00026: val_loss did not improve from 0.74290
# Epoch 27/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1598 - dice_coeff: 0.8401 - val_loss: 0.7784 - val_dice_coeff: 0.2179
#
# Epoch 00027: val_loss did not improve from 0.74290
# Epoch 28/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1591 - dice_coeff: 0.8409 - val_loss: 0.7668 - val_dice_coeff: 0.2293
#
# Epoch 00028: val_loss did not improve from 0.74290
# Epoch 29/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1530 - dice_coeff: 0.8471 - val_loss: 0.7522 - val_dice_coeff: 0.2437
#
# Epoch 00029: val_loss did not improve from 0.74290
# Epoch 30/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1474 - dice_coeff: 0.8524 - val_loss: 0.7414 - val_dice_coeff: 0.2543
#
# Epoch 00030: val_loss improved from 0.74290 to 0.74142, saving model to model.h5
# Epoch 31/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1463 - dice_coeff: 0.8536 - val_loss: 0.7822 - val_dice_coeff: 0.2142
#
# Epoch 00031: val_loss did not improve from 0.74142
# Epoch 32/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1407 - dice_coeff: 0.8594 - val_loss: 0.7474 - val_dice_coeff: 0.2484
#
# Epoch 00032: val_loss did not improve from 0.74142
# Epoch 33/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1523 - dice_coeff: 0.8480 - val_loss: 0.7665 - val_dice_coeff: 0.2296
#
# Epoch 00033: val_loss did not improve from 0.74142
# Epoch 34/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1392 - dice_coeff: 0.8605 - val_loss: 0.7532 - val_dice_coeff: 0.2427
#
# Epoch 00034: val_loss did not improve from 0.74142
# Epoch 35/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1364 - dice_coeff: 0.8636 - val_loss: 0.7209 - val_dice_coeff: 0.2745
#
# Epoch 00035: val_loss improved from 0.74142 to 0.72086, saving model to model.h5
# Epoch 36/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1599 - dice_coeff: 0.8407 - val_loss: 0.7414 - val_dice_coeff: 0.2543
#
# Epoch 00036: val_loss did not improve from 0.72086
# Epoch 37/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1338 - dice_coeff: 0.8667 - val_loss: 0.7616 - val_dice_coeff: 0.2344
#
# Epoch 00037: val_loss did not improve from 0.72086
# Epoch 38/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1296 - dice_coeff: 0.8705 - val_loss: 0.7609 - val_dice_coeff: 0.2352
#
# Epoch 00038: val_loss did not improve from 0.72086
# Epoch 39/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1326 - dice_coeff: 0.8677 - val_loss: 0.7699 - val_dice_coeff: 0.2263
#
# Epoch 00039: val_loss did not improve from 0.72086
# Epoch 40/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1293 - dice_coeff: 0.8702 - val_loss: 0.7287 - val_dice_coeff: 0.2668
#
# Epoch 00040: val_loss did not improve from 0.72086
# Epoch 41/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1285 - dice_coeff: 0.8717 - val_loss: 0.7510 - val_dice_coeff: 0.2448
#
# Epoch 00041: val_loss did not improve from 0.72086
# Epoch 42/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1258 - dice_coeff: 0.8742 - val_loss: 0.7687 - val_dice_coeff: 0.2274
#
# Epoch 00042: val_loss did not improve from 0.72086
# Epoch 43/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1232 - dice_coeff: 0.8769 - val_loss: 0.7407 - val_dice_coeff: 0.2550
#
# Epoch 00043: val_loss did not improve from 0.72086
# Epoch 44/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1248 - dice_coeff: 0.8755 - val_loss: 0.7597 - val_dice_coeff: 0.2363
#
# Epoch 00044: val_loss did not improve from 0.72086
# Epoch 45/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1203 - dice_coeff: 0.8797 - val_loss: 0.7622 - val_dice_coeff: 0.2339
#
# Epoch 00045: val_loss did not improve from 0.72086
# Epoch 46/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1185 - dice_coeff: 0.8815 - val_loss: 0.7722 - val_dice_coeff: 0.2240
#
# Epoch 00046: val_loss did not improve from 0.72086
# Epoch 47/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1177 - dice_coeff: 0.8823 - val_loss: 0.7544 - val_dice_coeff: 0.2416
#
# Epoch 00047: val_loss did not improve from 0.72086
# Epoch 48/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1183 - dice_coeff: 0.8819 - val_loss: 0.7762 - val_dice_coeff: 0.2201
#
# Epoch 00048: val_loss did not improve from 0.72086
# Epoch 49/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1225 - dice_coeff: 0.8766 - val_loss: 0.7707 - val_dice_coeff: 0.2255
#
# Epoch 00049: val_loss did not improve from 0.72086
# Epoch 50/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1197 - dice_coeff: 0.8805 - val_loss: 0.7640 - val_dice_coeff: 0.2321
#
# Epoch 00050: val_loss did not improve from 0.72086
# Epoch 51/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1151 - dice_coeff: 0.8850 - val_loss: 0.7499 - val_dice_coeff: 0.2460
#
# Epoch 00051: val_loss did not improve from 0.72086
# Epoch 52/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1146 - dice_coeff: 0.8839 - val_loss: 0.7627 - val_dice_coeff: 0.2334
#
# Epoch 00052: val_loss did not improve from 0.72086
# Epoch 53/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1317 - dice_coeff: 0.8687 - val_loss: 0.7744 - val_dice_coeff: 0.2219
#
# Epoch 00053: val_loss did not improve from 0.72086
# Epoch 54/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1126 - dice_coeff: 0.8877 - val_loss: 0.7599 - val_dice_coeff: 0.2362
#
# Epoch 00054: val_loss did not improve from 0.72086
# Epoch 55/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1068 - dice_coeff: 0.8935 - val_loss: 0.7488 - val_dice_coeff: 0.2470
#
# Epoch 00055: val_loss did not improve from 0.72086
# Epoch 56/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1050 - dice_coeff: 0.8948 - val_loss: 0.7545 - val_dice_coeff: 0.2414
#
# Epoch 00056: val_loss did not improve from 0.72086
# Epoch 57/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.1055 - dice_coeff: 0.8947 - val_loss: 0.7687 - val_dice_coeff: 0.2275
#
# Epoch 00057: val_loss did not improve from 0.72086
# Epoch 58/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1058 - dice_coeff: 0.8944 - val_loss: 0.7393 - val_dice_coeff: 0.2564
#
# Epoch 00058: val_loss did not improve from 0.72086
# Epoch 59/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1044 - dice_coeff: 0.8958 - val_loss: 0.7518 - val_dice_coeff: 0.2441
#
# Epoch 00059: val_loss did not improve from 0.72086
# Epoch 60/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1037 - dice_coeff: 0.8963 - val_loss: 0.7452 - val_dice_coeff: 0.2506
#
# Epoch 00060: val_loss did not improve from 0.72086
# Epoch 61/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1002 - dice_coeff: 0.9000 - val_loss: 0.7780 - val_dice_coeff: 0.2184
#
# Epoch 00061: val_loss did not improve from 0.72086
# Epoch 62/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1015 - dice_coeff: 0.8986 - val_loss: 0.7508 - val_dice_coeff: 0.2451
#
# Epoch 00062: val_loss did not improve from 0.72086
# Epoch 63/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1020 - dice_coeff: 0.8980 - val_loss: 0.7633 - val_dice_coeff: 0.2328
#
# Epoch 00063: val_loss did not improve from 0.72086
# Epoch 64/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1004 - dice_coeff: 0.8999 - val_loss: 0.7609 - val_dice_coeff: 0.2352
#
# Epoch 00064: val_loss did not improve from 0.72086
# Epoch 65/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0997 - dice_coeff: 0.9005 - val_loss: 0.7504 - val_dice_coeff: 0.2455
#
# Epoch 00065: val_loss did not improve from 0.72086
# Epoch 66/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0974 - dice_coeff: 0.9029 - val_loss: 0.7634 - val_dice_coeff: 0.2327
#
# Epoch 00066: val_loss did not improve from 0.72086
# Epoch 67/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0990 - dice_coeff: 0.9011 - val_loss: 0.7511 - val_dice_coeff: 0.2448
#
# Epoch 00067: val_loss did not improve from 0.72086
# Epoch 68/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0961 - dice_coeff: 0.9040 - val_loss: 0.7639 - val_dice_coeff: 0.2322
#
# Epoch 00068: val_loss did not improve from 0.72086
# Epoch 69/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0944 - dice_coeff: 0.9054 - val_loss: 0.7576 - val_dice_coeff: 0.2384
#
# Epoch 00069: val_loss did not improve from 0.72086
# Epoch 70/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0999 - dice_coeff: 0.8984 - val_loss: 0.7407 - val_dice_coeff: 0.2550
#
# Epoch 00070: val_loss did not improve from 0.72086
# Epoch 71/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.1064 - dice_coeff: 0.8935 - val_loss: 0.7866 - val_dice_coeff: 0.2098
#
# Epoch 00071: val_loss did not improve from 0.72086
# Epoch 72/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0976 - dice_coeff: 0.9023 - val_loss: 0.7401 - val_dice_coeff: 0.2556
#
# Epoch 00072: val_loss did not improve from 0.72086
# Epoch 73/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0920 - dice_coeff: 0.9079 - val_loss: 0.7543 - val_dice_coeff: 0.2416
#
# Epoch 00073: val_loss did not improve from 0.72086
# Epoch 74/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0934 - dice_coeff: 0.9055 - val_loss: 0.7395 - val_dice_coeff: 0.2562
#
# Epoch 00074: val_loss did not improve from 0.72086
# Epoch 75/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0981 - dice_coeff: 0.9017 - val_loss: 0.7596 - val_dice_coeff: 0.2364
#
# Epoch 00075: val_loss did not improve from 0.72086
# Epoch 76/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0973 - dice_coeff: 0.9028 - val_loss: 0.7454 - val_dice_coeff: 0.2504
#
# Epoch 00076: val_loss did not improve from 0.72086
# Epoch 77/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0903 - dice_coeff: 0.9098 - val_loss: 0.7576 - val_dice_coeff: 0.2384
#
# Epoch 00077: val_loss did not improve from 0.72086
# Epoch 78/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0923 - dice_coeff: 0.9078 - val_loss: 0.7583 - val_dice_coeff: 0.2377
#
# Epoch 00078: val_loss did not improve from 0.72086
# Epoch 79/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0914 - dice_coeff: 0.9082 - val_loss: 0.7423 - val_dice_coeff: 0.2534
#
# Epoch 00079: val_loss did not improve from 0.72086
# Epoch 80/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0911 - dice_coeff: 0.9091 - val_loss: 0.7443 - val_dice_coeff: 0.2514
#
# Epoch 00080: val_loss did not improve from 0.72086
# Epoch 81/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0889 - dice_coeff: 0.9113 - val_loss: 0.7606 - val_dice_coeff: 0.2354
#
# Epoch 00081: val_loss did not improve from 0.72086
# Epoch 82/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0883 - dice_coeff: 0.9118 - val_loss: 0.7463 - val_dice_coeff: 0.2495
#
# Epoch 00082: val_loss did not improve from 0.72086
# Epoch 83/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0877 - dice_coeff: 0.9124 - val_loss: 0.7457 - val_dice_coeff: 0.2500
#
# Epoch 00083: val_loss did not improve from 0.72086
# Epoch 84/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0860 - dice_coeff: 0.9141 - val_loss: 0.7430 - val_dice_coeff: 0.2527
#
# Epoch 00084: val_loss did not improve from 0.72086
# Epoch 85/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0882 - dice_coeff: 0.9120 - val_loss: 0.7427 - val_dice_coeff: 0.2530
#
# Epoch 00085: val_loss did not improve from 0.72086
# Epoch 86/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0875 - dice_coeff: 0.9126 - val_loss: 0.7502 - val_dice_coeff: 0.2457
#
# Epoch 00086: val_loss did not improve from 0.72086
# Epoch 87/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0837 - dice_coeff: 0.9160 - val_loss: 0.7562 - val_dice_coeff: 0.2397
#
# Epoch 00087: val_loss did not improve from 0.72086
# Epoch 88/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0937 - dice_coeff: 0.9064 - val_loss: 0.7585 - val_dice_coeff: 0.2375
#
# Epoch 00088: val_loss did not improve from 0.72086
# Epoch 89/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0844 - dice_coeff: 0.9153 - val_loss: 0.7310 - val_dice_coeff: 0.2645
#
# Epoch 00089: val_loss did not improve from 0.72086
# Epoch 90/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0845 - dice_coeff: 0.9154 - val_loss: 0.7585 - val_dice_coeff: 0.2375
#
# Epoch 00090: val_loss did not improve from 0.72086
# Epoch 91/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0844 - dice_coeff: 0.9155 - val_loss: 0.7528 - val_dice_coeff: 0.2431
#
# Epoch 00091: val_loss did not improve from 0.72086
# Epoch 92/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0847 - dice_coeff: 0.9148 - val_loss: 0.7241 - val_dice_coeff: 0.2713
#
# Epoch 00092: val_loss did not improve from 0.72086
# Epoch 93/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0897 - dice_coeff: 0.9104 - val_loss: 0.7383 - val_dice_coeff: 0.2573
#
# Epoch 00093: val_loss did not improve from 0.72086
# Epoch 94/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0820 - dice_coeff: 0.9181 - val_loss: 0.7414 - val_dice_coeff: 0.2543
#
# Epoch 00094: val_loss did not improve from 0.72086
# Epoch 95/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0834 - dice_coeff: 0.9168 - val_loss: 0.7435 - val_dice_coeff: 0.2522
#
# Epoch 00095: val_loss did not improve from 0.72086
# Epoch 96/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0852 - dice_coeff: 0.9148 - val_loss: 0.7401 - val_dice_coeff: 0.2556
#
# Epoch 00096: val_loss did not improve from 0.72086
# Epoch 97/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0818 - dice_coeff: 0.9184 - val_loss: 0.7484 - val_dice_coeff: 0.2474
#
# Epoch 00097: val_loss did not improve from 0.72086
# Epoch 98/100
# 3550/3550 [==============================] - 43s 12ms/step - loss: 0.0807 - dice_coeff: 0.9193 - val_loss: 0.7302 - val_dice_coeff: 0.2653
#
# Epoch 00098: val_loss did not improve from 0.72086
# Epoch 99/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.0838 - dice_coeff: 0.9161 - val_loss: 0.7439 - val_dice_coeff: 0.2518
#
# Epoch 00099: val_loss did not improve from 0.72086
# Epoch 100/100
# 3550/3550 [==============================] - 44s 12ms/step - loss: 0.0813 - dice_coeff: 0.9186 - val_loss: 0.7310 - val_dice_coeff: 0.2645
#
# Epoch 00100: val_loss did not improve from 0.72086

# %% [markdown]
# #Test it!
# Now that the model is trained, we can test our segmentation tool on the test holdout cases. Note that the prediction is the probability that a pixel is object (pancreas) or not object (anything other than pancreas). We use 0.5 as the threshold for deciding Pancreas or not, though again you can adjust this if your task might view it as more valuable to include non-pancreas pixels in order to reduce the number of missed pancreas pixels.
# Note also that we calculate the Dice Score. The Dice calculated in training is not the actual Dice score, but it is proportional (we make adjustments so it is never 0 or have a divide by 0 error), and therefore works.

# %%
# !ls
# Out:
# gdrive	  sample_data  testmasks    trainmasks	validationimages
# model.h5  testimages   trainimages  Unet_trial	validationmasks

# %%
# Cell 6
model.load_weights("./model.h5")
preds_test = model.predict(test_X, verbose=1)
preds_test = (preds_test > 0.5).astype(np.uint8)

def np_dice(true, pred):
    intersection = np.sum(true * pred)
    dc =(2.0 * intersection) / (np.sum(true) + np.sum(pred))
    return dc

fig=plt.figure(figsize=(130, 130), dpi = 100)

for j in range(0,8,2):

    # add while loop to find mask
    fMask = 0
    while fMask < 100:
        i = random.randint(0,test_X.shape[0]-1)
        image = test_X[i,...,0]
        mask =  test_Y[i,...,0]
        flattened = [val for sublist in mask for val in sublist]
        fMask = sum(flattened)

    mask = ma.masked_where(mask == 0, mask)
    pred = preds_test[i,...,0]
    pred = ma.masked_where(pred == 0, pred)
    
    fig.add_subplot(8, 2, j+1)
    plt.imshow(image, cmap = "gray")
    plt.imshow(mask, 'cool', alpha=0.7)
    plt.title("Ground Truth")
    plt.axis('off')
    
    fig.add_subplot(8, 2, j+2)
    plt.imshow(image, cmap = "gray")
    plt.imshow(pred, 'cool', alpha=0.7)
    plt.title("Prediction")
    plt.axis('off')
    
plt.subplots_adjust(bottom=0.1, left = 0.01, right=0.05, top=0.3)
plt.show()

print("The dice score for this model is: ", np_dice(test_Y, preds_test))
# Out:
# 1070/1070 [==============================] - 4s 4ms/step
# The dice score for this model is:  0.6383430653450224
